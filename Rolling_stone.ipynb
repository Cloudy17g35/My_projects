# %% [markdown]
# ## Rolling Stone top 500 albums analysis

# %% [markdown]
# This is project about top 500 albums of all time from based on the Rolling Stone magazine. First we re gonna import the pandas module:

# %%
import pandas as pd

# %% [markdown]
# And store the data set to the pandas Data Frame

# %%
file = open('albumlist.csv')
df = pd.read_csv(file, index_col=0)

# %% [markdown]
# Now we re gonna see how many rows and columns our set have

# %%
df.shape
# Out:
# (500, 5)

# %% [markdown]
# It contains 500 rows and 5 columns

# %% [markdown]
# Name and the describe of the column

# %% [markdown]
# |name|description|
# |:----:|:----:|
# |Position on the list|album index in the list|
# |Year|Year of release|
# |Album|album name|
# |Artist|name of the artist or artists|
# |Genre|Name of the genre for example rock, pop, jazz, blues|
# |Subgenre|Subgenre name - like folk rock, psychodelic rock|

# %% [markdown]
# Here we gonna see the data types of the table columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500 entries, 1 to 500
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Year      500 non-null    int64
#  1   Album     500 non-null    object
#  2   Artist    500 non-null    object
#  3   Genre     500 non-null    object
#  4   Subgenre  500 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 23.4+ KB

# %%
df[df["Artist"] == "Bob Dylan"]
# Out:
#         Year                       Album     Artist  \
# Number
# 4       1965        Highway 61 Revisited  Bob Dylan
# 9       1966            Blonde on Blonde  Bob Dylan
# 16      1975         Blood on the Tracks  Bob Dylan
# 31      1965   Bringing It All Back Home  Bob Dylan
# 97      1963  The Freewheelin' Bob Dylan  Bob Dylan
# 174     1976                      Desire  Bob Dylan
# 204     2006                Modern Times  Bob Dylan
# 303     1967         John Wesley Harding  Bob Dylan
# 385     2001            "Love and Theft"  Bob Dylan
# 410     1997            Time Out of Mind  Bob Dylan
#
#                                Genre                     Subgenre
# Number
# 4                               Rock        Folk Rock, Blues Rock
# 9                        Rock, Blues    Folk Rock, Rhythm & Blues
# 16                              Rock  Folk Rock, Acoustic, Ballad
# 31      Rock, Folk, World, & Country              Folk Rock, Folk
# ...

# %% [markdown]
# According to the numpy we can do it also like this but the example above is way much cleaner

# %%
df.loc[:,'Genre']
# Out:
# Number
# 1           Rock
# 2           Rock
# 3           Rock
# 4           Rock
# 5      Rock, Pop
#          ...
# 496         Rock
# 497         Rock
# 498         Rock
# 499        Blues
# 500      Hip Hop
# Name: Genre, Length: 500, dtype: object

# %% [markdown]
# When we wanna select the multiple columns:

# %%
df[["Genre", "Artist"]]
# Out:
#             Genre             Artist
# Number
# 1            Rock        The Beatles
# 2            Rock     The Beach Boys
# 3            Rock        The Beatles
# 4            Rock          Bob Dylan
# 5       Rock, Pop        The Beatles
# ...           ...                ...
# 496          Rock         Boz Scaggs
# 497          Rock  The White Stripes
# 498          Rock    The Stone Roses
# 499         Blues          B.B. King
# 500       Hip Hop            OutKast
#
# [500 rows x 2 columns]

# %% [markdown]
# Numpy explanation again

# %%
df.loc[:,["Genre", "Artist"]]
# Out:
#             Genre             Artist
# Number
# 1            Rock        The Beatles
# 2            Rock     The Beach Boys
# 3            Rock        The Beatles
# 4            Rock          Bob Dylan
# 5       Rock, Pop        The Beatles
# ...           ...                ...
# 496          Rock         Boz Scaggs
# 497          Rock  The White Stripes
# 498          Rock    The Stone Roses
# 499         Blues          B.B. King
# 500       Hip Hop            OutKast
#
# [500 rows x 2 columns]

# %% [markdown]
# When we re slicing something peculliar gonna happen

# %%
df.loc[:,"Artist": "Subgenre"]
# Out:
#                    Artist      Genre  \
# Number
# 1             The Beatles       Rock
# 2          The Beach Boys       Rock
# 3             The Beatles       Rock
# 4               Bob Dylan       Rock
# 5             The Beatles  Rock, Pop
# ...                   ...        ...
# 496            Boz Scaggs       Rock
# 497     The White Stripes       Rock
# 498       The Stone Roses       Rock
# 499             B.B. King      Blues
# 500               OutKast    Hip Hop
#
#                                                  Subgenre
# Number
# 1                           Rock & Roll, Psychedelic Rock
# 2                              Pop Rock, Psychedelic Rock
# 3                              Psychedelic Rock, Pop Rock
# 4                                   Folk Rock, Blues Rock
# 5                                                Pop Rock
# ...                                                   ...
# 496                                              Pop Rock
# ...

# %% [markdown]
# last column gonna be included to the slice

# %% [markdown]
# Now when we leaarned how to select column by the label, let's learn how to select rows

# %%
df.loc[3] #  It's the way how we selecting the whole row
# Out:
# Year                              1966
# Album                         Revolver
# Artist                     The Beatles
# Genre                             Rock
# Subgenre    Psychedelic Rock, Pop Rock
# Name: 3, dtype: object

# %% [markdown]
# And multiple rows:

# %%
df.loc[[1,5,499]]
# Out:
#         Year                                  Album       Artist      Genre  \
# Number
# 1       1967  Sgt. Pepper's Lonely Hearts Club Band  The Beatles       Rock
# 5       1965                            Rubber Soul  The Beatles  Rock, Pop
# 499     1971               Live in Cook County Jail    B.B. King      Blues
#
#                              Subgenre
# Number
# 1       Rock & Roll, Psychedelic Rock
# 5                            Pop Rock
# 499                    Electric Blues

# %% [markdown]
# Selecting slice:

# %%
s = df.loc[1:40]

# %% [markdown]
# Again the 40th row is included

# %%
s
# Out:
#         Year                                              Album  \
# Number
# 1       1967              Sgt. Pepper's Lonely Hearts Club Band
# 2       1966                                         Pet Sounds
# 3       1966                                           Revolver
# 4       1965                               Highway 61 Revisited
# 5       1965                                        Rubber Soul
# 6       1971                                    What's Going On
# 7       1972                                  Exile on Main St.
# 8       1979                                     London Calling
# 9       1966                                   Blonde on Blonde
# 10      1968                    The Beatles ("The White Album")
# 11      1976                                   The Sun Sessions
# 12      1959                                       Kind of Blue
# 13      1967                      The Velvet Underground & Nico
# ...

# %% [markdown]
# The type is data frame

# %%
type(s)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Because series and dataframes are two distinct objects, they have their own unique methods

# %%
artists = df["Artist"]

artists_value_counts = artists.value_counts()
artists_value_counts[:10]
# Out:
# The Beatles           10
# The Rolling Stones    10
# Bob Dylan             10
# Bruce Springsteen      8
# The Who                7
# David Bowie            5
# Led Zeppelin           5
# Various Artists        5
# Radiohead              5
# U2                     5
# Name: Artist, dtype: int64

# %% [markdown]
# In the resulting series, we can see each unique non-null value in the column and their counts.

# %% [markdown]
# When we wanna see for examply only count of Bob Dylan's Albums:

# %%
artists_value_counts["Bob Dylan"]
# Out:
# 10

# %% [markdown]
# For example we wanna have also the Bawid Bowie and the Beatles album's count:

# %%
artists_value_counts[["The Beatles", "David Bowie", "Bob Dylan"]]
# Out:
# The Beatles    10
# David Bowie     5
# Bob Dylan      10
# Name: Artist, dtype: int64

# %% [markdown]
# Now I' m gonna select the newest album(s) on this list

# %%
df["Year"].max()
# Out:
# 2011

# %%
df[df["Year"] == 2011]
# Out:
#         Year               Album          Artist Genre  \
# Number
# 381     2011  The Smile Sessions  The Beach Boys  Rock
#
#                           Subgenre
# Number
# 381     Pop Rock, Psychedelic Rock

# %% [markdown]
# This album is just released in this year, but it was recorded in 1966-1967, so I m gonna look also for 2010

# %%
df[df["Year"] == 2010]
# Out:
#         Year                              Album      Artist    Genre Subgenre
# Number
# 353     2010  My Beautiful Dark Twisted Fantasy  Kanye West  Hip Hop     None

# %% [markdown]
# Here we have "My Beautiful Dark Twisted Fantasy" by Kayne West

# %% [markdown]
# Lets see the oldest one

# %%
min_year = df["Year"].min()

# %%
df[df["Year"] == min_year]
# Out:
#         Year                   Album         Artist      Genre  \
# Number
# 101     1955  In the Wee Small Hours  Frank Sinatra  Jazz, Pop
#
#                 Subgenre
# Number
# 101     Big Band, Ballad

# %% [markdown]
# Here we have "In the Wee Small Hours" by Frank Sinatra

# %% [markdown]
# I'm also interested in the frequency table in this schema Genre:albums amount so:

# %%
genres = df['Genre']

artists_value_counts = genres.value_counts()
artists_value_counts[:20]
# Out:
# Rock                            249
# Funk / Soul                      38
# Hip Hop                          29
# Electronic, Rock                 19
# Rock, Pop                        18
# Rock, Blues                      16
# Folk, World, & Country           13
# Rock, Folk, World, & Country      9
# Blues                             8
# Jazz                              7
# Electronic                        7
# Funk / Soul, Pop                  6
# Reggae                            6
# Electronic, Pop                   5
# Rock, Funk / Soul                 5
# Funk / Soul, Blues                4
# Hip Hop, Funk / Soul              3
# Jazz, Pop                         3
# Rock, Funk / Soul, Pop            3
# Rock, Stage & Screen              3
# Name: Genre, dtype: int64

# %% [markdown]
# We can see that almost half is of all 500 albums is pure rock genre

# %%
genres = df['Year']

artists_value_counts = genres.value_counts()

# %%
df["Genre"].describe()
# Out:
# count      500
# unique      63
# top       Rock
# freq       249
# Name: Genre, dtype: object

# %% [markdown]
# Using the **method chainng** to achieve how many jazz albums are on the rolling stone list

# %%
df["Genre"].value_counts().loc["Jazz"]
# Out:
# 7

# %% [markdown]
# Using the method chaining to calculate the median year of each album

# %%
df['Year'].median(axis=0) #  we can also use axis = "index" as a parameter
#  defualt value for axis parameter is 0 so we even dont need to assign it
# Out:
# 1976.0

# %% [markdown]
# Using the describe method to look at the values

# %%
df.describe(include = ['O'])
# Out:
#                 Album       Artist Genre Subgenre
# count             500          500   500      500
# unique            497          289    63      290
# top     Greatest Hits  The Beatles  Rock     None
# freq                3           10   249       29

# %% [markdown]
# By default its gonna take the numeric values

# %%
df.describe()
# Out:
#               Year
# count   500.000000
# mean   1979.270000
# std      12.093701
# min    1955.000000
# 25%    1970.000000
# 50%    1976.000000
# 75%    1988.000000
# max    2011.000000

# %%
df
# Out:
#         Year                                  Album             Artist  \
# Number
# 1       1967  Sgt. Pepper's Lonely Hearts Club Band        The Beatles
# 2       1966                             Pet Sounds     The Beach Boys
# 3       1966                               Revolver        The Beatles
# 4       1965                   Highway 61 Revisited          Bob Dylan
# 5       1965                            Rubber Soul        The Beatles
# ...      ...                                    ...                ...
# 496     1969                             Boz Scaggs         Boz Scaggs
# 497     2001                      White Blood Cells  The White Stripes
# 498     1989                        The Stone Roses    The Stone Roses
# 499     1971               Live in Cook County Jail          B.B. King
# 500     1998                               Aquemini            OutKast
#
#             Genre                                           Subgenre
# Number
# ...

# %% [markdown]
# When we wanna find the particular column using the index and selecting the column:

# %%
df.loc[145,"Genre"]
# Out:
# 'Jazz, Rock'

# %% [markdown]
# Or the columns

# %%
df.loc[145, ["Genre", "Artist"]]
# Out:
# Genre     Jazz, Rock
# Artist    Steely Dan
# Name: 145, dtype: object

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-723480badb76> in <module>()
# ----> 1 pd.DataFrame(index = [chr(s) for s in range(97,102) ], columns=["X","Y", "Z", "I", "J"],data=np.arange(25))
#
# NameError: name 'np' is not defined
